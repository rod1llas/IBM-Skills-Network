# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Guillermo Hector Martinez Hesselink**
#
# Accountant

# %% [markdown]
# *I am interested in data science because it has the potential to make a meaningful impact in various fields such as healthcare, business, social sciences, and more.*

# %% [markdown]
# ### My code is going to define two variables called A and B and then print them

# %%
A = 5
B = 500
print(A)
print(B)
# Out:
# 5
# 500

# %% [markdown]
# Horizontal
# ___
# Rule
#
# | Column 1 | Column 2 | Column 3 |
# | --- | --- | --- |
# | Row 1, Column 1 | Row 1, Column 2 | Row 1, Column 3 |
# | Row 2, Column 1 | Row 2, Column 2 | Row 2, Column 3 |
#
# 1. First
# 2. Second
#     1. First of second
# 3. Third
